# %% [markdown]
# # Sales Prediction

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# ### Data Preprocessing

# %%
df = pd.read_csv('F:\\MSC Statistics KTHM\\Codsoft\\car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# ### Dropping not needed columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# ### Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Model Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 3s 82ms/step - loss: 0.4936 - mean_absolute_error: 0.6770 - val_loss: 0.4752 - val_mean_absolute_error: 0.6620
# Epoch 2/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3827 - mean_absolute_error: 0.5928 - val_loss: 0.3732 - val_mean_absolute_error: 0.5826
# Epoch 3/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2876 - mean_absolute_error: 0.5087 - val_loss: 0.2796 - val_mean_absolute_error: 0.4975
# Epoch 4/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1995 - mean_absolute_error: 0.4151 - val_loss: 0.1830 - val_mean_absolute_error: 0.3907
# Epoch 5/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1182 - mean_absolute_error: 0.3076 - val_loss: 0.1021 - val_mean_absolute_error: 0.2740
# Epoch 6/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0596 - mean_absolute_error: 0.2075 - val_loss: 0.0504 - val_mean_absolute_error: 0.1775
# Epoch 7/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0298 - mean_absolute_error: 0.1388 - val_loss: 0.0284 - val_mean_absolute_error: 0.1331
# Epoch 8/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0203 - mean_absolute_error: 0.1103 - val_loss: 0.0225 - val_mean_absolute_error: 0.1201
# Epoch 9/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0190 - mean_absolute_error: 0.1063 - val_loss: 0.0211 - val_mean_absolute_error: 0.1175
# Epoch 10/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0186 - mean_absolute_error: 0.1054 - val_loss: 0.0206 - val_mean_absolute_error: 0.1155
# Epoch 11/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0178 - mean_absolute_error: 0.1030 - val_loss: 0.0203 - val_mean_absolute_error: 0.1139
# Epoch 12/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0172 - mean_absolute_error: 0.1012 - val_loss: 0.0201 - val_mean_absolute_error: 0.1131
# Epoch 13/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0167 - mean_absolute_error: 0.0997 - val_loss: 0.0198 - val_mean_absolute_error: 0.1124
# Epoch 14/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0162 - mean_absolute_error: 0.0984 - val_loss: 0.0193 - val_mean_absolute_error: 0.1109
# Epoch 15/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0159 - mean_absolute_error: 0.0973 - val_loss: 0.0187 - val_mean_absolute_error: 0.1089
# Epoch 16/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0154 - mean_absolute_error: 0.0961 - val_loss: 0.0183 - val_mean_absolute_error: 0.1079
# Epoch 17/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0151 - mean_absolute_error: 0.0951 - val_loss: 0.0180 - val_mean_absolute_error: 0.1072
# Epoch 18/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0148 - mean_absolute_error: 0.0941 - val_loss: 0.0176 - val_mean_absolute_error: 0.1060
# Epoch 19/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0144 - mean_absolute_error: 0.0932 - val_loss: 0.0173 - val_mean_absolute_error: 0.1053
# Epoch 20/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0141 - mean_absolute_error: 0.0923 - val_loss: 0.0171 - val_mean_absolute_error: 0.1048
# Epoch 21/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0138 - mean_absolute_error: 0.0913 - val_loss: 0.0168 - val_mean_absolute_error: 0.1039
# Epoch 22/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0136 - mean_absolute_error: 0.0905 - val_loss: 0.0165 - val_mean_absolute_error: 0.1030
# Epoch 23/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0133 - mean_absolute_error: 0.0897 - val_loss: 0.0162 - val_mean_absolute_error: 0.1022
# Epoch 24/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0131 - mean_absolute_error: 0.0889 - val_loss: 0.0159 - val_mean_absolute_error: 0.1014
# Epoch 25/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0128 - mean_absolute_error: 0.0881 - val_loss: 0.0157 - val_mean_absolute_error: 0.1005
# Epoch 26/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0126 - mean_absolute_error: 0.0873 - val_loss: 0.0154 - val_mean_absolute_error: 0.0998
# Epoch 27/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0124 - mean_absolute_error: 0.0866 - val_loss: 0.0152 - val_mean_absolute_error: 0.0992
# Epoch 28/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0122 - mean_absolute_error: 0.0858 - val_loss: 0.0150 - val_mean_absolute_error: 0.0985
# Epoch 29/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0120 - mean_absolute_error: 0.0852 - val_loss: 0.0149 - val_mean_absolute_error: 0.0980
# Epoch 30/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0845 - val_loss: 0.0146 - val_mean_absolute_error: 0.0971
# Epoch 31/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0116 - mean_absolute_error: 0.0837 - val_loss: 0.0143 - val_mean_absolute_error: 0.0960
# Epoch 32/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0114 - mean_absolute_error: 0.0829 - val_loss: 0.0140 - val_mean_absolute_error: 0.0951
# Epoch 33/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0112 - mean_absolute_error: 0.0823 - val_loss: 0.0139 - val_mean_absolute_error: 0.0948
# Epoch 34/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0110 - mean_absolute_error: 0.0816 - val_loss: 0.0137 - val_mean_absolute_error: 0.0942
# Epoch 35/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0109 - mean_absolute_error: 0.0810 - val_loss: 0.0134 - val_mean_absolute_error: 0.0930
# Epoch 36/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0107 - mean_absolute_error: 0.0802 - val_loss: 0.0133 - val_mean_absolute_error: 0.0926
# Epoch 37/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0105 - mean_absolute_error: 0.0796 - val_loss: 0.0131 - val_mean_absolute_error: 0.0920
# Epoch 38/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0104 - mean_absolute_error: 0.0790 - val_loss: 0.0129 - val_mean_absolute_error: 0.0914
# Epoch 39/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0102 - mean_absolute_error: 0.0783 - val_loss: 0.0126 - val_mean_absolute_error: 0.0905
# Epoch 40/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0101 - mean_absolute_error: 0.0776 - val_loss: 0.0124 - val_mean_absolute_error: 0.0897
# Epoch 41/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0099 - mean_absolute_error: 0.0770 - val_loss: 0.0122 - val_mean_absolute_error: 0.0890
# Epoch 42/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0098 - mean_absolute_error: 0.0764 - val_loss: 0.0121 - val_mean_absolute_error: 0.0886
# Epoch 43/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0096 - mean_absolute_error: 0.0758 - val_loss: 0.0119 - val_mean_absolute_error: 0.0877
# Epoch 44/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0095 - mean_absolute_error: 0.0751 - val_loss: 0.0116 - val_mean_absolute_error: 0.0868
# Epoch 45/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0093 - mean_absolute_error: 0.0745 - val_loss: 0.0114 - val_mean_absolute_error: 0.0861
# Epoch 46/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0092 - mean_absolute_error: 0.0740 - val_loss: 0.0112 - val_mean_absolute_error: 0.0853
# Epoch 47/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0090 - mean_absolute_error: 0.0733 - val_loss: 0.0110 - val_mean_absolute_error: 0.0846
# Epoch 48/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0089 - mean_absolute_error: 0.0726 - val_loss: 0.0108 - val_mean_absolute_error: 0.0837
# Epoch 49/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0087 - mean_absolute_error: 0.0721 - val_loss: 0.0106 - val_mean_absolute_error: 0.0830
# Epoch 50/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0086 - mean_absolute_error: 0.0714 - val_loss: 0.0104 - val_mean_absolute_error: 0.0820

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# # Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.6164289721128677
